# %%
import requests

for i in range(10):
    html = requests.post(
        'https://leetcode.com/graphql/',

        # json={"query":"query userPublicProfile($username: String!) {\n  matchedUser(username: $username) {\n    contestBadge {\n      name\n      expired\n      hoverText\n      icon\n    }\n    username\n    githubUrl\n    twitterUrl\n    linkedinUrl\n    profile {\n      ranking\n      userAvatar\n      realName\n      aboutMe\n      school\n      websites\n      countryName\n      company\n      jobTitle\n      skillTags\n      postViewCount\n      postViewCountDiff\n      reputation\n      reputationDiff\n      solutionCount\n      solutionCountDiff\n      categoryDiscussCount\n      categoryDiscussCountDiff\n    }\n  }\n}\n    ","variables":{"username":"chienhsiang-hung"}}
        json={
            "variables": {},
            "query": "{\n  globalRanking(page: "+str(1)+") {\n    totalUsers\n    userPerPage\n    myRank {\n      ranking\n      currentGlobalRanking\n      currentRating\n      dataRegion\n      user {\n        nameColor\n        activeBadge {\n          displayName\n          icon\n          __typename\n        }\n        __typename\n      }\n      __typename\n    }\n    rankingNodes {\n      ranking\n      currentRating\n      currentGlobalRanking\n      dataRegion\n      user {\n        username\n        nameColor\n        activeBadge {\n          displayName\n          icon\n          __typename\n        }\n        profile {\n          userAvatar\n          countryCode\n          countryName\n          realName\n          __typename\n        }\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
        }
    )

    for rankingNode in html.json()['data']['globalRanking']['rankingNodes']:
        if rankingNode['user']

# %%
import requests
# client = requests.session()
# Retrieve the CSRF token first
# client.get('https://leetcode.com/chienhsiang-hung/') # Sets cookie
# csrftoken = client.cookies['csrftoken']
# print(client.cookies)
# LEETCODE_SESSION = client.cookies['LEETCODE_SESSION']

# https://leetcode.com/discuss/general-discussion/1297705/is-there-public-api-endpoints-available-for-leetcode
html = requests.post(
    'https://leetcode.com/graphql/',
    # headers = {
    #     'referer': 'https://leetcode.com/chienhsiang-hung/',
    #     'cookie': f'csrftoken={csrftoken}'
    # },
    
    # json={"query":"query userPublicProfile($username: String!) {\n  matchedUser(username: $username) {\n    contestBadge {\n      name\n      expired\n      hoverText\n      icon\n    }\n    username\n    githubUrl\n    twitterUrl\n    linkedinUrl\n    profile {\n      ranking\n      userAvatar\n      realName\n      aboutMe\n      school\n      websites\n      countryName\n      company\n      jobTitle\n      skillTags\n      postViewCount\n      postViewCountDiff\n      reputation\n      reputationDiff\n      solutionCount\n      solutionCountDiff\n      categoryDiscussCount\n      categoryDiscussCountDiff\n    }\n  }\n}\n    ","variables":{"username":"chienhsiang-hung"}}
    json={
        "variables": {},
        "query": "{\n  globalRanking(page: "+str(1)+") {\n    totalUsers\n    userPerPage\n    myRank {\n      ranking\n      currentGlobalRanking\n      currentRating\n      dataRegion\n      user {\n        nameColor\n        activeBadge {\n          displayName\n          icon\n          __typename\n        }\n        __typename\n      }\n      __typename\n    }\n    rankingNodes {\n      ranking\n      currentRating\n      currentGlobalRanking\n      dataRegion\n      user {\n        username\n        nameColor\n        activeBadge {\n          displayName\n          icon\n          __typename\n        }\n        profile {\n          userAvatar\n          countryCode\n          countryName\n          realName\n          __typename\n        }\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
    }
)
html.json()['data']['globalRanking']['rankingNodes']
# Out:
# [{'ranking': '[11, 1, 1, 1, 2, 18, 1, 3, 65, 1, 2, 1, 3, 1, 5, 69, 17, 146, 7, 1, 21, 5, 21, 76, 9, 1, 1, 1, 1, 1, 2, 3, 4, 57, 7, 1, 1, 2, 2, 1, 3, 3, 2, 1, 2, 3, 2, 1, 1, 3, 1]',
#   'currentRating': '3686.191',
#   'currentGlobalRanking': 1,
#   'dataRegion': 'US',
#   'user': {'username': 'neal_wu',
#    'nameColor': 'legendary',
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://assets.leetcode.com/users/neal_wu/avatar_1574529913.png',
#     'countryCode': 'US',
#     'countryName': 'United States',
#     'realName': '',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[377, 8, 638, 447, 3, 340, 70, 776, 219, 43, 53, 1, 34, 3, 28, 93, 139, 196, 57, 9, 240, 45, 33, 54, 170, 4, 1, 35, 12, 110, 856, 100, 27, 2, 598, 1, 16, 74, 26, 2, 88, 217, 22, 38, 10, 2, 10, 26, 18, 2, 18, 11, 4, 69, 1, 15, 12, 238, 20, 12, 58, 51, 3, 20, 120, 4, 4, 12, 12, 9, 121, 2, 1, 1, 3, 2, 1, 1, 2, 443, 1]',
#   'currentRating': '3653.750517002495',
#   'currentGlobalRanking': 2,
#   'dataRegion': 'US',
#   'user': {'username': 'numb3r5',
#    'nameColor': 'legendary',
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://s3-us-west-1.amazonaws.com/s3-lc-upload/assets/default_avatar.jpg',
#     'countryCode': 'AU',
#     'countryName': 'Australia',
#     'realName': '',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[234, 193, 189, 181, 325, 103, 154, 96, 622, 120, 89, 116, 281, 765, 57, 191, 404, 37, 56, 62, 112, 110, 139, 51, 276, 250, 787, 90, 99, 224, 521, 203, 174, 438, 84, 176, 71, 622, 401, 279, 108, 148, 148, 4, 5, 31, 330, 2, 9, 16, 8, 5, 9, 4, 17, 2, 20, 30, 5, 7, 8, 319, 23, 42, 13, 24, 10, 3, 4, 14, 170, 1, 20, 6, 20, 4, 5, 18, 11, 2, 17, 8, 11, 8, 6, 7]',
#   'currentRating': '3516.7215449059036',
#   'currentGlobalRanking': 3,
#   'dataRegion': 'US',
#   'user': {'username': 'nyu_ldf',
#    'nameColor': 'legendary',
#    'activeBadge': {'displayName': '50 Days Badge 2022',
#     'icon': 'https://leetcode.com/static/images/badges/2022/lg/2022-annual-50.png',
#     '__typename': 'UserBadgeNode'},
#    'profile': {'userAvatar': 'https://assets.leetcode.com/users/xinxin2020/avatar_1577860037.png',
#     'countryCode': '',
#     'countryName': None,
#     'realName': 'nyu_ldf',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[29, 1, 3, 11, 13, 6, 34, 2, 1, 3, 10, 7, 8, 13, 2, 7, 27, 5, 3, 5, 5, 10, 28, 4, 19, 12, 9, 25, 6, 53, 16, 5, 1, 5, 1]',
#   'currentRating': '3489.204',
#   'currentGlobalRanking': 4,
#   'dataRegion': 'CN',
#   'user': {'username': 'int65536',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://s3-us-west-1.amazonaws.com/s3-lc-upload/assets/default_avatar.jpg',
#     'countryCode': '',
#     'countryName': '中国',
#     'realName': 'int65536',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[17, 3, 4, 39, 6, 1, 3, 14, 2, 2, 15, 9, 31, 4, 42, 6, 5, 17, 1, 4, 204, 4, 5, 1, 10, 1, 7, 8, 73, 35, 34, 4, 23, 39, 12, 9, 472, 12, 133, 14, 12, 9, 1, 3, 5, 11, 5, 4, 15, 7, 2, 4, 57, 3, 22, 19, 11, 1, 24, 6, 23, 9, 17, 19, 4, 24, 52, 3, 147, 6, 52, 5, 40, 11, 25, 4, 6, 2, 3, 5, 3, 16, 8, 41, 48, 3, 29, 2, 159, 29, 51, 3, 426, 3, 58, 1, 65, 11, 4, 53, 19, 5, 5, 5, 5, 9, 19,

#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[37, 4973, 11387, 18, 45, 49, 85, 7, 1, 36, 110, 3, 11, 4, 12, 233, 26, 110, 110, 31, 1, 187, 44, 37, 16, 51, 5, 8, 26, 31, 1, 1, 51, 8, 24, 243, 2012, 113, 2, 58, 36, 3, 67, 9, 38, 81, 43, 3, 48, 2, 198, 17, 72, 5, 30, 14, 3, 14, 198, 51, 26, 11, 14, 4, 4]',
#   'currentRating': '3367.6359101394883',
#   'currentGlobalRanking': 9,
#   'dataRegion': 'CN',
#   'user': {'username': 'moransky',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://aliyun-lc-upload.oss-cn-hangzhou.aliyuncs.com/aliyun-lc-upload/users/moransky/avatar_1657380252.png',
#     'countryCode': '',
#     'countryName': '中国',
#     'realName': '空',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[530, 196, 45, 3, 8, 14, 250, 26, 10, 3, 96, 1, 3, 4, 3, 3, 66, 11, 6, 100, 6, 4, 58, 2]',
#   'currentRating': '3365.1113371004335',
#   'currentGlobalRanking': 10,
#   'dataRegion': 'US',
#   'user': {'username': 'wwwwodddd',
#    'nameColor': 'legendary',
#    'activeBadge': {'displayName': '100 Days Badge 2022',
#     'icon': 'https://leetcode.com/static/images/badges/2022/lg/2022-annual-100.png',
#     '__typename': 'UserBadgeNode'},
#    'profile': {'userAvatar': 'https://assets.leetcode.com/users/avatars/avatar_1655637961.png',
#     'countryCode': 'US',
#     'countryName': 'United States',
#     'realName': 'wwwwodddd',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[652, 2090, 948, 1116, 280, 385, 232, 2159, 587, 371, 201, 128, 638, 24, 43, 108, 1, 41, 212, 66, 3, 2, 126, 1992, 1219, 20, 1637, 1, 38, 48, 41, 5, 9, 192, 95, 109, 47, 136, 14, 21, 59, 663, 27, 9, 58, 78, 1, 139, 15, 25, 8, 47, 162, 24, 1, 72, 48, 16, 67, 7, 28, 154, 52, 12, 35, 81, 1, 32, 6, 419, 46, 30, 94, 1, 19, 134, 17, 9, 19, 13, 21, 14, 60, 1, 1, 18, 9, 48, 7, 118, 5, 77, 7, 9, 7, 1, 50, 57, 20, 12, 1, 2, 45, 2, 10, 52, 5, 89, 3, 21, 24, 15, 1, 83, 67, 52, 5, 44, 2, 5, 21]',
#   'currentRating': '3357.485',
#   'currentGlobalRanking': 11,
#   'dataRegion': 'CN',
#   'user': {'username': 'wifiii',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://s3-us-west-1.amazonaws.com/s3-lc-upload/assets/default_avatar.jpg',
#     'countryCode': '',
#     'countryName': '',
#     'realName': 'wifiii',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[230, 46, 270, 21, 127, 8, 119, 99, 9, 49, 9, 215, 57, 17, 38, 21, 58, 15, 16, 28, 7, 63, 6, 89, 39, 11, 6, 27, 108, 13, 73, 30, 3, 39, 5, 18, 12, 9, 4, 1, 1, 2, 2, 4, 2, 2, 10, 4, 44, 1, 27, 8, 35, 1, 5, 37, 443, 23, 5, 11, 22, 3, 6, 5, 203, 4, 24, 8, 4, 34, 24, 9, 3, 23, 9, 8, 156, 21, 6, 9, 2, 10, 6, 8, 15, 31, 8, 2, 9, 28, 3, 63, 3, 45, 11, 8, 37, 1, 7, 1, 13, 30, 40, 10, 5, 7, 23, 28, 9, 1, 7, 36, 7, 10, 41, 10, 119, 4, 2, 16, 3, 25, 14, 17, 277, 18]',
#   'currentRating': '3354.5157631022157',
#   'currentGlobalRanking': 12,
#   'dataRegion': 'CN',
#   'user': {'username': 'Heltion',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://aliyun-lc-upload.oss-cn-hangzhou.aliyuncs.com/aliyun-lc-upload/users/heltion/avatar_1587213058.png',
#     'countryCode': '',
#     'countryName': '中国',
#     'realName': '何逊',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[198, 1, 1, 1, 1759, 119, 12, 1, 22, 7, 21, 1, 2, 18, 6, 1, 106, 1, 19, 12, 8, 10, 1, 4, 6, 1, 38, 217, 1, 1, 14, 1, 1, 14, 1, 6, 14, 12, 1, 163, 13, 1, 3, 16, 22, 536, 23, 11, 11, 77, 5]',
#   'currentRating': '3348.488302437398',
#   'currentGlobalRanking': 13,
#   'dataRegion': 'US',
#   'user': {'username': 'xiaowuc1',
#    'nameColor': 'legendary',
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://s3-us-west-1.amazonaws.com/s3-lc-upload/assets/default_avatar.jpg',
#     'countryCode': 'US',
#     'countryName': 'United States',
#     'realName': 'xiaowuc1',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[1594, 825, 1304, 55, 218, 198, 103, 404, 190, 311, 31, 105, 128, 852, 60, 188, 288, 6, 301, 17, 137, 138, 32, 13, 43, 74, 286, 28, 347, 20, 49, 62, 399, 18, 6, 3, 22, 361, 35, 105, 29, 112, 7, 14, 126, 13, 952, 144, 1, 2, 25, 5, 1487, 1, 63, 38, 56, 20, 28, 25, 78, 3, 2, 47, 6, 120, 2, 41, 4, 17, 5, 110]',
#   'currentRating': '3329.37532190456',
#   'currentGlobalRanking': 14,
#   'dataRegion': 'US',
#   'user': {'username': 'penguinhacker',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://s3-us-west-1.amazonaws.com/s3-lc-upload/assets/default_avatar.jpg',
#     'countryCode': '',
#     'countryName': None,
#     'realName': '',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[40, 73, 96, 44, 50, 5, 5, 5, 1, 2, 13, 23, 4, 20, 248, 3, 2, 2, 1, 2, 139, 1, 5, 23, 4, 13, 1, 18, 1, 7, 17]',
#   'currentRating': '3312.286',
#   'currentGlobalRanking': 15,
#   'dataRegion': 'US',
#   'user': {'username': 'tmwilliamlin168',
#    'nameColor': 'legendary',
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://assets.leetcode.com/users/tmwilliamlin168/avatar_1581176013.png',
#     'countryCode': 'TW',
#     'countryName': 'Taiwan',
#     'realName': 'William Lin',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[27, 5, 31, 7, 9, 10, 281, 51, 17, 89, 3, 1, 5, 4, 1, 275, 5, 29, 31, 21, 10, 17, 30, 176, 1, 5, 432, 18, 14, 18, 24, 41, 7, 416, 44, 45, 5, 21, 3, 11, 27, 50, 81, 33, 8, 61, 10, 228, 35, 113, 20, 23, 11, 10, 53, 70, 17, 108, 7, 4, 12, 2, 80, 10, 13, 17, 18, 19, 9, 103]',
#   'currentRating': '3299.818248813627',
#   'currentGlobalRanking': 16,
#   'dataRegion': 'US',
#   'user': {'username': 'jonathanirvings',
#    'nameColor': 'legendary',
#    'activeBadge': {'displayName': '50 Days Badge 2022',
#     'icon': 'https://leetcode.com/static/images/badges/2022/lg/2022-annual-50.png',
#     '__typename': 'UserBadgeNode'},
#    'profile': {'userAvatar': 'https://s3-us-west-1.amazonaws.com/s3-lc-upload/assets/default_avatar.jpg',
#     'countryCode': 'SG',
#     'countryName': 'Singapore',
#     'realName': 'Jonathan Irvin Gunawan',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[38, 1, 2, 4, 54, 8, 9, 3, 71, 26, 2, 41, 99, 1, 10, 4, 158, 6, 37, 5, 104, 9, 1940, 2, 5, 30]',
#   'currentRating': '3267.987983319291',
#   'currentGlobalRanking': 17,
#   'dataRegion': 'CN',
#   'user': {'username': 'wwwwodddd',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://aliyun-lc-upload.oss-cn-hangzhou.aliyuncs.com/aliyun-lc-upload/users/wwwwodddd/avatar_1665033235.png',
#     'countryCode': '',
#     'countryName': '中国',
#     'realName': 'wwwwodddd',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[44, 12, 63, 5, 45, 8, 25, 86, 131, 10, 9, 14, 17, 16, 19, 18, 14, 9, 2, 23, 25, 9, 2, 12, 3, 25, 66, 1, 6, 10, 27, 144, 281, 218, 3, 25, 3, 2, 53, 7, 31, 7, 555, 10, 45, 93, 384, 1, 33, 5, 88, 14, 36, 16, 44, 12, 317, 14, 157, 3, 24, 8, 4, 15, 7, 10, 84, 13, 2, 9, 3, 30, 13, 53, 15, 11, 11, 29, 19, 7, 14, 15, 1, 1, 17, 112, 92]',
#   'currentRating': '3257.9032099609317',
#   'currentGlobalRanking': 18,
#   'dataRegion': 'US',
#   'user': {'username': 'hitonanode',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://assets.leetcode.com/users/hitonanode/avatar_1594984583.png',
#     'countryCode': 'JP',
#     'countryName': 'Japan',
#     'realName': 'hitonanode',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[196, 4, 1889, 40, 17, 93, 337, 117, 8, 54, 263, 4, 18, 10, 114, 55, 1, 8, 379, 35, 1, 7, 22, 79, 30, 97, 17, 42, 24, 398, 8, 73, 164, 19, 31, 15, 62, 11, 36, 18, 24, 37, 19, 50, 11, 21, 13, 10, 40, 5, 667, 10, 80, 4, 9, 2]',
#   'currentRating': '3253.248',
#   'currentGlobalRanking': 19,
#   'dataRegion': 'CN',
#   'user': {'username': 'lucifer1005',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://aliyun-lc-upload.oss-cn-hangzhou.aliyuncs.com/aliyun-lc-upload/users/lucifer1005/avatar_1653919335.png',
#     'countryCode': '',
#     'countryName': '',
#     'realName': 'hide on bush',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[27, 6, 36, 10, 11, 2, 60, 3, 2, 2, 10, 60, 35, 17, 10, 5, 3, 24, 15, 5, 123, 13, 5, 24, 6, 20, 40, 2, 10, 56, 15, 42, 4, 9, 2, 1, 5, 2, 6, 6, 3, 2, 6, 13, 18, 19, 10, 14, 15, 34, 25, 10, 26, 17, 2, 15, 11, 10, 92, 24, 63, 49, 6, 15, 47, 9, 2, 84, 15, 4, 13, 32, 2, 3, 18, 36, 57, 41, 8, 5, 3, 4, 4, 21, 22, 33, 17, 3, 6, 17, 6, 2, 10, 3, 39, 6, 82, 6, 68, 20, 27, 5, 10, 3, 9, 5, 20, 4, 31, 58, 37, 6, 7, 64, 10, 167, 18, 93, 10, 5, 43, 72, 38, 4, 26, 30, 11, 12, 7, 12, 13, 124, 3, 108, 92, 113, 13, 42, 74, 32, 13, 19, 21, 8, 5, 2, 15, 56, 32, 19, 48, 5, 54, 64, 6, 27, 17, 3, 19, 23, 1, 244, 14, 49, 123, 6, 14, 13, 3, 12, 11, 10, 2, 57, 11, 10, 78, 34, 74, 14, 561, 4, 9, 179, 4, 14, 60, 83, 33, 187, 13, 36, 13, 161, 76, 72, 40, 52, 131, 230, 27, 223, 14, 6, 55, 25, 8, 11, 32, 241, 41, 67, 36, 21, 39, 16, 5, 15]',
#   'currentRating': '3248.2046569238564',
#   'currentGlobalRanking': 20,
#   'dataRegion': 'US',
#   'user': {'username': 'natsugiri',
#    'nameColor': None,
#    'activeBadge': {'displayName': '50 Days Badge 2022',
#     'icon': 'https://leetcode.com/static/images/badges/2022/lg/2022-annual-50.png',
#     '__typename': 'UserBadgeNode'},
#    'profile': {'userAvatar': 'https://s3-us-west-1.amazonaws.com/s3-lc-upload/assets/default_avatar.jpg',
#     'countryCode': 'JP',
#     'countryName': 'Japan',
#     'realName': 'natsugiri',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[136, 259, 313, 209, 293, 715, 116, 249, 547, 206, 389, 172, 1133, 346, 709, 799, 229, 887, 65, 1024, 1017, 160, 639, 1810, 57, 517, 145, 148, 256, 25, 334, 1989, 123, 6, 179, 326, 45, 3, 19, 75, 4, 266, 1, 37, 1432, 42, 1, 20, 100, 272, 1, 11, 43, 2, 8, 308, 10]',
#   'currentRating': '3241.1922612630487',
#   'currentGlobalRanking': 21,
#   'dataRegion': 'US',
#   'user': {'username': 'qeetcode',
#    'nameColor': None,
#    'activeBadge': {'displayName': 'Dec LeetCoding Challenge',
#     'icon': '/static/images/badges/dcc-2021-12.png',
#     '__typename': 'UserBadgeNode'},
#    'profile': {'userAvatar': 'https://assets.leetcode.com/users/rainingpeace/avatar_1617292193.png',
#     'countryCode': 'US',
#     'countryName': 'United States',
#     'realName': 'Sam Lee',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[1786, 6507, 1582, 2500, 1161, 7563, 2251, 3843, 448, 688, 834, 1621, 5217, 8183, 850, 589, 3008, 5584, 898, 1615, 125, 979, 728, 229, 118, 676, 438, 74, 1234, 29, 16, 492, 323, 376, 482, 974, 1026, 17, 9, 166, 313, 407, 75, 14, 116, 869, 17, 186, 13, 39, 64, 114, 1583, 489, 13, 73, 84, 161, 56, 85, 124, 56, 16, 4, 23, 52, 105, 7, 126, 158, 6, 16, 1, 19]',
#   'currentRating': '3234.0204087740176',
#   'currentGlobalRanking': 22,
#   'dataRegion': 'CN',
#   'user': {'username': 'Yawn_Sean',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://aliyun-lc-upload.oss-cn-hangzhou.aliyuncs.com/aliyun-lc-upload/users/yawn_sean/avatar_1654149069.png',
#     'countryCode': '',
#     'countryName': '中国',
#     'realName': '小羊肖恩',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[308, 40, 56, 69, 93, 902, 19, 230, 51, 323, 112, 244, 83, 20, 83, 203, 37, 140, 233, 315, 109, 131, 156, 67, 27, 9, 91, 289, 44, 17, 9, 10, 36, 149, 172, 23, 121, 13, 151, 59, 84, 3990, 116, 73, 53, 135, 122, 14, 17, 12, 138, 106, 20, 11, 40, 264, 157, 27, 3, 77, 45, 235, 528, 289, 43, 63, 8, 24, 45, 7, 352, 42, 30, 12, 61, 54, 17, 5, 4, 123, 68, 89, 7, 9, 14, 3, 47, 119, 6, 3, 56, 35, 4, 3]',
#   'currentRating': '3230.135',
#   'currentGlobalRanking': 23,
#   'dataRegion': 'CN',
#   'user': {'username': 'lucifer1004',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://aliyun-lc-upload.oss-cn-hangzhou.aliyuncs.com/aliyun-lc-upload/users/lucifer1004/avatar_1623921450.png',
#     'countryCode': '',
#     'countryName': '中国',
#     'realName': '吴自华',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[415, 219, 110, 1005, 464, 88, 3, 3, 29, 13, 63, 7, 247, 6, 61, 89, 52, 2, 42, 35, 5, 3, 4]',
#   'currentRating': '3223.6449113744056',
#   'currentGlobalRanking': 24,
#   'dataRegion': 'US',
#   'user': {'username': 'bucketpotato',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://assets.leetcode.com/users/avatars/avatar_1668381644.png',
#     'countryCode': 'US',
#     'countryName': 'United States',
#     'realName': 'William Tsin',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'},
#  {'ranking': '[495, 534, 431, 46, 36, 203, 801, 1458, 9, 127, 1666, 594, 260, 267, 549, 21, 25, 91, 1, 168, 154, 23, 11, 15, 12, 8, 19, 79, 1, 26, 74, 2, 47, 699, 5, 108, 16, 24, 73, 29, 25, 14]',
#   'currentRating': '3214.7750856680073',
#   'currentGlobalRanking': 25,
#   'dataRegion': 'US',
#   'user': {'username': 'PurpleCrayon',
#    'nameColor': None,
#    'activeBadge': None,
#    'profile': {'userAvatar': 'https://assets.leetcode.com/users/rohingarg123/avatar_1584377597.png',
#     'countryCode': '',
#     'countryName': None,
#     'realName': 'Rohin Garg',
#     '__typename': 'UserProfileNode'},
#    '__typename': 'UserNode'},
#   '__typename': 'RankingNode'}]

# %%
import requests
# client = requests.session()
# Retrieve the CSRF token first
# client.get('https://leetcode.com/chienhsiang-hung/') # Sets cookie
# csrftoken = client.cookies['csrftoken']
# print(client.cookies)
# LEETCODE_SESSION = client.cookies['LEETCODE_SESSION']

# https://leetcode.com/discuss/general-discussion/1297705/is-there-public-api-endpoints-available-for-leetcode
html = requests.post(
    'https://leetcode.com/graphql/',
    # headers = {
    #     'referer': 'https://leetcode.com/chienhsiang-hung/',
    #     'cookie': f'csrftoken={csrftoken}'
    # },
    
    json={"query":"query userPublicProfile($username: String!) {\n  matchedUser(username: $username) {\n    contestBadge {\n      name\n      expired\n      hoverText\n      icon\n    }\n    username\n    githubUrl\n    twitterUrl\n    linkedinUrl\n    profile {\n      ranking\n      userAvatar\n      realName\n      aboutMe\n      school\n      websites\n      countryName\n      company\n      jobTitle\n      skillTags\n      postViewCount\n      postViewCountDiff\n      reputation\n      reputationDiff\n      solutionCount\n      solutionCountDiff\n      categoryDiscussCount\n      categoryDiscussCountDiff\n    }\n  }\n}\n    ","variables":{"username":"chienhsiang-hung"}}
    # json={
    #     "variables": {},
    #     "query": "{\n  globalRanking(page: "+str(1)+") {\n    totalUsers\n    userPerPage\n    myRank {\n      ranking\n      currentGlobalRanking\n      currentRating\n      dataRegion\n      user {\n        nameColor\n        activeBadge {\n          displayName\n          icon\n          __typename\n        }\n        __typename\n      }\n      __typename\n    }\n    rankingNodes {\n      ranking\n      currentRating\n      currentGlobalRanking\n      dataRegion\n      user {\n        username\n        nameColor\n        activeBadge {\n          displayName\n          icon\n          __typename\n        }\n        profile {\n          userAvatar\n          countryCode\n          countryName\n          realName\n          __typename\n        }\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
    # }
)
html.json()
# Out:
# {'data': {'matchedUser': {'contestBadge': None,
#    'username': 'chienhsiang-hung',
#    'githubUrl': 'https://github.com/chienhsiang-hung',
#    'twitterUrl': None,
#    'linkedinUrl': None,
#    'profile': {'ranking': 488648,
#     'userAvatar': 'https://assets.leetcode.com/users/avatars/avatar_1663853732.png',
#     'realName': '洪健翔 Hung, Chien-Hsiang',
#     'aboutMe': '',
#     'school': None,
#     'websites': ['https://chienhsiang-hung.github.io/blog/'],
#     'countryName': 'Taiwan',
#     'company': None,
#     'jobTitle': None,
#     'skillTags': [],
#     'postViewCount': 2518,
#     'postViewCountDiff': 580,
#     'reputation': 7,
#     'reputationDiff': 2,
#     'solutionCount': 73,
#     'solutionCountDiff': 7,
#     'categoryDiscussCount': 0,
#     'categoryDiscussCountDiff': 0}}}}
